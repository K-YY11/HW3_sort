# %%
def quick_sort(arr, start, end):
    if start >= end:
        return

    pivot = start
    left = start + 1
    right = end
    print(f"\n快速排序範圍: {arr[start:end+1]}")

    while left <= right:
        while left <= right and arr[right] >= arr[pivot]:
            right -= 1
        while left <= right and arr[left] <= arr[pivot]:
            left += 1
        if left < right:
            print(f"交換 {arr[left]} 和 {arr[right]}")
            arr[left], arr[right] = arr[right], arr[left]

    print(f"交換 pivot {arr[pivot]} 和 {arr[right]}")
    arr[pivot], arr[right] = arr[right], arr[pivot]
    print(f"目前結果: {arr}")

    quick_sort(arr, start, right - 1)
    quick_sort(arr, right + 1, end)


data = [33, 67, 8, 13, 54, 119, 3, 84, 25, 41]
print("原始數列:", data)
quick_sort(data, 0, len(data) - 1)
print("排序後數列:", data)
# Out:
# 原始數列: [33, 67, 8, 13, 54, 119, 3, 84, 25, 41]
#
# 快速排序範圍: [33, 67, 8, 13, 54, 119, 3, 84, 25, 41]
# 交換 67 和 25
# 交換 54 和 3
# 交換 pivot 33 和 3
# 目前結果: [3, 25, 8, 13, 33, 119, 54, 84, 67, 41]
#
# 快速排序範圍: [3, 25, 8, 13]
# 交換 pivot 3 和 3
# 目前結果: [3, 25, 8, 13, 33, 119, 54, 84, 67, 41]
#
# 快速排序範圍: [25, 8, 13]
# 交換 pivot 25 和 13
# 目前結果: [3, 13, 8, 25, 33, 119, 54, 84, 67, 41]
#
# 快速排序範圍: [13, 8]
# 交換 pivot 13 和 8
# 目前結果: [3, 8, 13, 25, 33, 119, 54, 84, 67, 41]
#
# 快速排序範圍: [119, 54, 84, 67, 41]
# 交換 pivot 119 和 41
# 目前結果: [3, 8, 13, 25, 33, 41, 54, 84, 67, 119]
#
# 快速排序範圍: [41, 54, 84, 67]
# 交換 pivot 41 和 41
# 目前結果: [3, 8, 13, 25, 33, 41, 54, 84, 67, 119]
#
# 快速排序範圍: [54, 84, 67]
# 交換 pivot 54 和 54
# 目前結果: [3, 8, 13, 25, 33, 41, 54, 84, 67, 119]
#
# 快速排序範圍: [84, 67]
# 交換 pivot 84 和 67
# 目前結果: [3, 8, 13, 25, 33, 41, 54, 67, 84, 119]
# 排序後數列: [3, 8, 13, 25, 33, 41, 54, 67, 84, 119]
